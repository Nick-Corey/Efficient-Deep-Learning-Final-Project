# %%
import os
os.environ["PYTHONUTF8"] = "1"

# %%
# %pip install "transformers>=4.44.0" datasets accelerate bitsandbytes peft trl evaluate sacrebleu rouge_score
# %pip install ipywidgets
# Out:
# Requirement already satisfied: transformers>=4.44.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (4.57.1)
# Requirement already satisfied: datasets in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (4.8.4)
# Requirement already satisfied: accelerate in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (1.13.0)
# Requirement already satisfied: bitsandbytes in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (0.49.2)
# Requirement already satisfied: peft in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (0.19.1)
# Requirement already satisfied: trl in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (1.2.0)
# Requirement already satisfied: evaluate in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (0.4.6)
# Requirement already satisfied: sacrebleu in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (2.6.0)
# Requirement already satisfied: rouge_score in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (0.1.2)
# Requirement already satisfied: filelock in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from transformers>=4.44.0) (3.29.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from transformers>=4.44.0) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from transformers>=4.44.0) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from transformers>=4.44.0) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from transformers>=4.44.0) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from transformers>=4.44.0) (2026.4.4)
# Requirement already satisfied: requests in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from transformers>=4.44.0) (2.33.1)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from transformers>=4.44.0) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from transformers>=4.44.0) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from transformers>=4.44.0) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.44.0) (2026.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.44.0) (4.15.0)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from datasets) (24.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from datasets) (2.3.3)
# Requirement already satisfied: httpx<1.0.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from datasets) (0.70.19)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.5)
# Requirement already satisfied: anyio in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from httpx<1.0.0->datasets) (4.13.0)
# Requirement already satisfied: certifi in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from httpx<1.0.0->datasets) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from httpx<1.0.0->datasets) (3.12)
# Requirement already satisfied: h11>=0.16 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: psutil in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from accelerate) (7.2.2)
# Requirement already satisfied: torch>=2.0.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from accelerate) (2.11.0)
# Requirement already satisfied: setuptools<82 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from torch>=2.0.0->accelerate) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: portalocker in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from sacrebleu) (3.2.0)
# Requirement already satisfied: tabulate>=0.8.9 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from sacrebleu) (0.10.0)
# Requirement already satisfied: colorama in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from sacrebleu) (6.1.0)
# Requirement already satisfied: absl-py in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from rouge_score) (2.4.0)
# Requirement already satisfied: nltk in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from rouge_score) (3.9.4)
# Requirement already satisfied: six>=1.14.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from requests->transformers>=4.44.0) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from requests->transformers>=4.44.0) (2.6.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: click in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from nltk->rouge_score) (8.3.2)
# Requirement already satisfied: joblib in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from nltk->rouge_score) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from pandas->datasets) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from pandas->datasets) (2026.1)
# Requirement already satisfied: pywin32>=226 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from portalocker->sacrebleu) (311)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipywidgets in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from ipywidgets) (8.39.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: colorama in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: exceptiongroup in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.20.0)
# Requirement already satisfied: stack_data in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.15.0)
# Requirement already satisfied: wcwidth in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\tyier\miniconda3\envs\qlora310\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from datasets import load_dataset
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TrainingArguments, Trainer
from peft import LoraConfig, get_peft_model, TaskType
import evaluate

# %%
dataset = load_dataset("opus_books", "en-es")
dataset = dataset["train"].train_test_split(test_size=0.05, seed=42)

def rename_columns(example):
    return {
        "src": example["translation"]["en"],
        "tgt": example["translation"]["es"],
    }

dataset = dataset.map(rename_columns, remove_columns=dataset["train"].column_names)

print(dataset)
print(dataset["train"][0])
# Out:
# Map:   0%|          | 0/88796 [00:00<?, ? examples/s]
# Map:   0%|          | 0/4674 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['src', 'tgt'],
#         num_rows: 88796
#     })
#     test: Dataset({
#         features: ['src', 'tgt'],
#         num_rows: 4674
#     })
# })
# {'src': '"That which has happened me in meeting you, mighty prince," replied Don Quixote, "cannot be unfortunate, even if my fall had not stopped short of the depths of the bottomless pit, for the glory of having seen you would have lifted me up and delivered me from it.', 'tgt': '-El que yo he tenido en veros, valeroso príncipe -respondió don Quijote-, es imposible ser malo, aunque mi caída no parara hasta el profundo de los abismos, pues de allí me levantara y me sacara la gloria de haberos visto.'}

# %%
def build_prompt(src, tgt=None):
    user = f"Translate this from English to Spanish:\n{src}"
    if tgt is None:
        return f"User: {user}\nAssistant:"
    else:
        return f"User: {user}\nAssistant: {tgt}"

# %%
baseline_model_id = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"

baseline_tokenizer = AutoTokenizer.from_pretrained(baseline_model_id, use_fast=True)
baseline_tokenizer.pad_token = baseline_tokenizer.eos_token

baseline_model = AutoModelForCausalLM.from_pretrained(
    baseline_model_id,
    device_map="auto",
)

# %%
def generate_translation(model, tokenizer, src_text, max_new_tokens=80):
    prompt = build_prompt(src_text)
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    outputs = model.generate(
        **inputs,
        max_new_tokens=max_new_tokens,
        do_sample=False,
        pad_token_id=tokenizer.eos_token_id,
    )

    decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)

    if "Assistant:" in decoded:
        return decoded.split("Assistant:")[-1].strip()
    return decoded.strip()

# %%
test_subset = dataset["test"].select(range(20))

baseline_predictions = []
references = []
sources = []

for example in test_subset:
    src = example["src"]
    tgt = example["tgt"]

    pred = generate_translation(baseline_model, baseline_tokenizer, src)

    sources.append(src)
    references.append(tgt)
    baseline_predictions.append(pred)

print("BASELINE EXAMPLE")
print("SRC:", sources[0])
print("REF:", references[0])
print("PRED:", baseline_predictions[0])

# %%
bleu = evaluate.load("sacrebleu")
baseline_bleu = bleu.compute(
    predictions=baseline_predictions,
    references=[[ref] for ref in references]
)

print("Baseline BLEU:", baseline_bleu)

# %%
del baseline_model
torch.cuda.empty_cache()

# %%
model_id = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16,
)

tokenizer = AutoTokenizer.from_pretrained(model_id, use_fast=True)
tokenizer.pad_token = tokenizer.eos_token

model = AutoModelForCausalLM.from_pretrained(
    model_id,
    quantization_config=bnb_config,
    device_map="auto",
)

# %%
lora_config = LoraConfig(
    r=8,
    lora_alpha=16,
    lora_dropout=0.05,
    bias="none",
    task_type=TaskType.CAUSAL_LM,
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj"],
)

model = get_peft_model(model, lora_config)
model.print_trainable_parameters()

# %%
max_length = 256

def preprocess(example):
    prompt = build_prompt(example["src"], example["tgt"])
    tokens = tokenizer(
        prompt,
        max_length=max_length,
        truncation=True,
        padding="max_length",
    )
    tokens["labels"] = tokens["input_ids"].copy()
    return tokens

tokenized = dataset.map(
    preprocess,
    batched=False,
    remove_columns=dataset["train"].column_names,
)

# %%
training_args = TrainingArguments(
    output_dir="./tinyllama-qlora-translation",
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    gradient_accumulation_steps=4,
    learning_rate=1e-4,
    num_train_epochs=3,
    logging_steps=50,
    eval_strategy="steps",
    eval_steps=200,
    save_steps=200,
    save_total_limit=2,
    bf16=True,
    gradient_checkpointing=True,
    lr_scheduler_type="cosine",
    report_to="none",
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized["train"],
    eval_dataset=tokenized["test"],
)

trainer.train()

# %%
qlora_predictions = []

for src in sources:
    pred = generate_translation(model, tokenizer, src)
    qlora_predictions.append(pred)

print("QLORA EXAMPLE")
print("SRC:", sources[0])
print("REF:", references[0])
print("PRED:", qlora_predictions[0])

# %%
qlora_bleu = bleu.compute(
    predictions=qlora_predictions,
    references=[[ref] for ref in references]
)

print("QLoRA BLEU:", qlora_bleu)

# %%
for i in range(5):
    print("=" * 80)
    print("SOURCE:   ", sources[i])
    print("REFERENCE:", references[i])
    print("BASELINE: ", baseline_predictions[i])
    print("QLORA:    ", qlora_predictions[i])
